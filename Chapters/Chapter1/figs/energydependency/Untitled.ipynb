# %%
#Reference Reaction :   238U(n,f) 
#Neutron        Cross          Uncertainty    Uncertainty      
#energy         section        (barn)         (%)              
#(MeV)          (barn)

# %%
import numpy as np
data = np.loadtxt("238U_nf_Reference_xs_data.txt")
import matplotlib.pyplot as plt
plt.loglog(data[:,0],data[:,1])

# %%
# %inci
