# %%
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

#plt.style.use("kit")
fig = plt.figure(figsize=(9,6))
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-3, 9, 0.005)
Y = np.arange(-3, 9, 0.005)
X, Y = np.meshgrid(X, Y)

Z = np.exp(-X**2-Y**2)

# Plot the surface.
ax.plot_surface(X, Y, Z, cmap=cm.Blues,
                       linewidth=0, antialiased=False,alpha=0.8,zorder=1)


t =4 
omx = 1/np.sqrt(2)
omy = 1/np.sqrt(2)
sigmaa = 0.1
Z1 = np.exp(-(X-omx*t)**2-(Y-omy*t)**2)*np.exp(-sigmaa*t)
# Plot the surface.
ax.plot_surface(X, Y, Z, cmap=cm.Blues,
                       linewidth=0, antialiased=False,alpha =0.8,zorder=2)



t = 8
Z2 = np.exp(-(X-omx*t)**2-(Y-omy*t)**2)*np.exp(-sigmaa*t)
# Plot the surface.
ax.plot_surface(X, Y, Z, cmap=cm.Blues,
                       linewidth=0, antialiased=False,alpha=0.8,zorder=3)


# Customize the z axis.
ax.set_zlim(0, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.w_zaxis.line.set_lw(0.)
ax.set_zticks([])

ax.set_xlabel(r"$x$")
ax.set_ylabel(r"$y$")


# Add a color bar which maps values to colors.
# make the panes transparent
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
# make the grid lines transparent
ax.xaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.yaxis._axinfo["grid"]['color'] =  (1,1,1,0)
ax.zaxis._axinfo["grid"]['color'] =  (1,1,1,0)

ax.set_xticks([])
ax.set_yticks([])
ax.w_xaxis.line.set_lw(0.)
ax.w_yaxis.line.set_lw(0.)


plt.show()

# %%
ZZtmp =np.maximum(Z,Z1)
ZZ = np.maximum(ZZtmp,Z2)

# %%
plt.style.use("kit")
fig = plt.figure()#figsize=(12,4))
ax = fig.gca(projection='3d')



# Plot the surface.
surf = ax.plot_surface(X, Y, ZZ, cmap=cm.Greys,antialiased=False,
                        alpha=1.0,zorder=1,edgecolor='none',rstride=5, cstride=5,vmin=-1, vmax=1.0,)



ax.set_xlabel(r"$x$")
ax.set_ylabel(r"$y$")


# Add a color bar which maps values to colors.
# make the panes transparent
#ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
#ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
#ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
# make the grid lines transparent
#ax.xaxis._axinfo["grid"]['color'] =  (1,1,1,0)
#ax.yaxis._axinfo["grid"]['color'] =  (1,1,1,0)
#ax.zaxis._axinfo["grid"]['color'] =  (1,1,1,0)
plt.axis('off')
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
#ax.w_xaxis.line.set_lw(0.)
#ax.w_yaxis.line.set_lw(0.)
#ax.w_zaxis.line.set_lw(0.)
plt.grid(b=None)
plt.show()
# The fix
for spine in ax.spines.values():
    spine.set_visible(False)

plt.tight_layout()

s2 = np.sqrt(2)
ax.text(0,0,1,r'$t=0$',zorder=100,horizontalalignment='center')
ax.text(4/s2,4/s2,0.7,r'$t=4$',zorder=100,horizontalalignment='center')
ax.text(8/s2,8/s2,0.5,r'$t=8$',zorder=100,horizontalalignment='center')

fig.savefig("1.png")
