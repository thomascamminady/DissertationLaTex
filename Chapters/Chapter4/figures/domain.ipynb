# %%
import kitcolors as kit 
import matplotlib.pyplot as plt

# %%
plt.style.use("kitish")

fig, ax = plt.subplots()

off = 0.5
ax.spines['left'].set_position(('data', off))
ax.set_yticks([])

ax.set_xticks([])
ax.text(0.5,-0.1,"$x=0$",ha = "center")
ax.spines['bottom'].set_position(('data', off))
ax.spines['bottom'].set_color('none')


left = 0.25
ax.text(left,0.7,"$\psi_u^L,\,\, \psi_c^L$ ",ha="center",va="center")
ax.text(left,0.5,"$\sigma_u^L,\,\, \sigma_c^L$ ",ha="center",va="center")
ax.text(left,0.3,"$Q_u^L$ ",ha="center",va="center")

left = 0.75
ax.text(left,0.7,"$\psi_u^R,\,\, \psi_c^R$ ",ha="center",va="center")
ax.text(left,0.5,"$\sigma_u^R,\,\, \sigma_c^R$ ",ha="center",va="center")
ax.text(left,0.3,"$Q_u^R$ ",ha="center",va="center")


ax.set_xlim([0,1])
ax.set_ylim([0,1])
# Out:
# (0.0, 1.0)
