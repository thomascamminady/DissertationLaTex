# %%
using Revise
include("newquadrature/Quadrature.jl")
using DelimitedFiles
using LinearAlgebra
println("done")
# Out:
# done

# %%
for order = 4:2:20
    for qtype in [2,3]
        for prefix in ["l","s"]
            Q = Quadrature(order,qtype,prefix=="s")
            writedlm(string(order)*"_"*string(qtype)*"_"*prefix*"_weights.txt",Q.weights)
        end
    end
end
# Out:
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
