# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import matplotlib.colors as colors
import numpy as np 

divnorm = colors.DivergingNorm(vmin=-500, vcenter=0, vmax=4000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6007314fb69e> in <module>
#       4 import numpy as np
#       5
# ----> 6 divnorm = colors.DivergingNorm(vmin=-500, vcenter=0, vmax=4000)
#
# AttributeError: module 'matplotlib.colors' has no attribute 'DivergingNorm'
