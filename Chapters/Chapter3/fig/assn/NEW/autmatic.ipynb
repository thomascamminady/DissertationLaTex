# %%
import numpy as np
import pandas as pd 
import os
import numpy as np 
from camminapy import snpp

# %%
prefix = "/home/qd4314/Work/Projects/rSN/code/out"
#sf = [x for x in os.listdir(prefix)]
#df = pd.DataFrame()
#for i, folder in enumerate(sf):
#    foldername = prefix + "/" + folder
#    config = lspp(foldername)
#    df = df.append(config, ignore_index=True)

# %%
df.to_csv("df.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a297e6da3344> in <module>
# ----> 1 df.to_csv("df.csv")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd 
from camminapy import createheatmap

# %%
df = pd.read_csv("df.csv")
tmp = df[df["nx"]==200.0]

# %%
createheatmap(tmp,200,92,safetyfactor=1.1,filename="tmp11.pdf")
