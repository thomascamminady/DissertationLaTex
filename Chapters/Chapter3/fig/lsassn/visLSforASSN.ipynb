# %%
import numpy as np
import pandas as pd 
import os
import numpy as np 
from camminapy import snpp
from camminapy import createheatmap
import matplotlib.pyplot as plt 
prefix = "/home/qd4314/Work/Projects/rSN/code/out/"
if True:
    sf = [x for x in os.listdir(prefix)]
    sf = ["2020-07-29T12:50:04.603"]
    sf = ["2020-07-29T12:54:25.179","2020-07-29T12:56:08.095"]
    for i, folder in enumerate(sf):
        foldername = prefix + "/" + folder
        config = snpp(foldername,plotflag = True)
        print(config)
#        df = df.append(config, ignore_index=True)
#    df.to_csv("tmplog.csv")
# Out:
# {'nx': 200.0, 'ny': 200.0, 'cfl': 0.95, 'quadraturetype': 3.0, 'quadratureorder': 4.0, 'convolutionmagnitude': 4.0, 'convolutionwidth': 8.0, 'convolutiontoscattering': 0.0, 'rotationmagnitude': 0.0, 'testcaseid': 1.0, 'periodicXflag': 0.0, 'periodicYflag': 0.0, 'dim1flag': 0.0, 'whichrank': 0.0, 'L1': 5.947104774569257, 'L2': 5.615644948525002}
# {'nx': 200.0, 'ny': 200.0, 'cfl': 0.95, 'quadraturetype': 3.0, 'quadratureorder': 4.0, 'convolutionmagnitude': 18.0, 'convolutionwidth': 3.5, 'convolutiontoscattering': 0.0, 'rotationmagnitude': 0.0, 'testcaseid': 1.0, 'periodicXflag': 0.0, 'periodicYflag': 0.0, 'dim1flag': 0.0, 'whichrank': 0.0, 'L1': 13.251653699391198, 'L2': 8.393085946492128}
